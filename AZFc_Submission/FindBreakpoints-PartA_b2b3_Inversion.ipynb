# %%
import pandas as pd
import pysam
import os
import json

# %%
comp = str.maketrans("ACGTNacgtn", "TGCANtgcan")
#rc = str(CordSeq3+CordSeq4).translate(comp)[::-1]

# %% [markdown]
# # assemblies

# %%
assemblyDict={}
directory='/LeeLab/Assemblies/HPRC_Release2/chrY_assemblies/'
for file in os.listdir(directory):
    if '.fai' in file or '.gzi' in file or '.DS' in file:
        continue
    else:
        assemblyDict[file.split("_")[0]]= directory+file
print(len(assemblyDict))
# Out:
# 143

# %%
df = pd.read_csv("/LeeLab/HPRC/chromosomeY/Data/DavidPorubsky/AZFc_ColorBLock_Clusters_12162025.csv")

# %% [markdown]
# ## pairings

# %%
b2b3Inversions=[
    ['HG01109','NA19331'],
    ['HG01074','NA19331'],
    ['NA21093','HG03009'],
    ['NA20870','HG02040']/HG03579,
    ['HG02074','HG02392']
]

# %% [markdown]
# ## Pull sequences

# %%
coordinate1 = 'HG01074_chrY:23760130-23988958'
CordSeq1 = ''.join(pysam.faidx(assemblyDict['HG01074'], coordinate1).split()[1:])
coordinate2 = 'HG01074_chrY:24716263-24969499'
CordSeq2 = ''.join(pysam.faidx(assemblyDict['HG01074'], coordinate2).split()[1:])
coordinate3 = 'NA19331_chrY:23943835-24197196'
CordSeq3 = ''.join(pysam.faidx(assemblyDict['NA19331'], coordinate3).split()[1:])
coordinate4 = 'NA19331_chrY:24919749-25148445'
CordSeq4 = ''.join(pysam.faidx(assemblyDict['NA19331'], coordinate4).split()[1:])
#with open('/Breakpoints/b2b3Inversion/alignments/HG01074_NA19331_b2b3Inversion_breakpoint.fasta', 'a+') as file:
    file.write('>'+str(coordinate1)+'_Front\n')
    file.write(CordSeq1+"\n")
    file.write('>'+str(coordinate2)+'_Back\n')
    file.write(str(CordSeq2).translate(comp)[::-1]+"\n")
    file.write('>'+str(coordinate3)+'_Front\n')
    file.write(CordSeq3+"\n")
    file.write('>'+str(coordinate4)+'_Back\n')
    file.write(str(CordSeq4).translate(comp)[::-1]+"\n")
file.close()

# %%
coordinate1 = 'NA21093_chrY:23439487-23668726'
CordSeq1 = ''.join(pysam.faidx(assemblyDict['NA21093'], coordinate1).split()[1:])
coordinate2 = 'NA21093_chrY:24384075-24637842'
CordSeq2 = ''.join(pysam.faidx(assemblyDict['NA21093'], coordinate2).split()[1:])
coordinate3 = 'HG03009_chrY:24449274-24702610'
CordSeq3 = ''.join(pysam.faidx(assemblyDict['HG03009'], coordinate3).split()[1:])
coordinate4 = 'HG03009_chrY:25417963-25647200'
CordSeq4 = ''.join(pysam.faidx(assemblyDict['HG03009'], coordinate4).split()[1:])
#with open('/Breakpoints/b2b3Inversion/alignments/NA21093_HG03009_b2b3Inversion_breakpoint.fasta', 'a+') as file:
    file.write('>'+str(coordinate1)+'_Front\n')
    file.write(CordSeq1+"\n")
    file.write('>'+str(coordinate2)+'_Back\n')
    file.write(str(CordSeq2).translate(comp)[::-1]+"\n")
    file.write('>'+str(coordinate3)+'_Front\n')
    file.write(CordSeq3+"\n")
    file.write('>'+str(coordinate4)+'_Back\n')
    file.write(str(CordSeq4).translate(comp)[::-1]+"\n")
file.close()

# %%
coordinate1 = 'NA20870_chrY:23498031-23726851'
CordSeq1 = ''.join(pysam.faidx(assemblyDict['NA20870'], coordinate1).split()[1:])
coordinate2 = 'NA20870_chrY:24435052-24688288'
CordSeq2 = ''.join(pysam.faidx(assemblyDict['NA20870'], coordinate2).split()[1:])
coordinate3 = 'HG02040_chrY:24061998-24315357'
CordSeq3 = ''.join(pysam.faidx(assemblyDict['HG02040'], coordinate3).split()[1:])
coordinate4 = 'HG02040_chrY:25035553-25264261'
CordSeq4 = ''.join(pysam.faidx(assemblyDict['HG02040'], coordinate4).split()[1:])
#with open('/Breakpoints/b2b3Inversion/alignments/NA20870_HG02040_b2b3Inversion_breakpoint.fasta', 'a+') as file:
    file.write('>'+str(coordinate1)+'_Front\n')
    file.write(CordSeq1+"\n")
    file.write('>'+str(coordinate2)+'_Back\n')
    file.write(str(CordSeq2).translate(comp)[::-1]+"\n")
    file.write('>'+str(coordinate3)+'_Front\n')
    file.write(CordSeq3+"\n")
    file.write('>'+str(coordinate4)+'_Back\n')
    file.write(str(CordSeq4).translate(comp)[::-1]+"\n")
file.close()

# %%
coordinate1 = 'HG02074_chrY:24169028-24397832'
CordSeq1 = ''.join(pysam.faidx(assemblyDict['HG02074'], coordinate1).split()[1:])
coordinate2 = 'HG02074_chrY:25139438-25393182'
CordSeq2 = ''.join(pysam.faidx(assemblyDict['HG02074'], coordinate2).split()[1:])
coordinate3 = 'HG02392_chrY:23690500-23943836'
CordSeq3 = ''.join(pysam.faidx(assemblyDict['HG02392'], coordinate3).split()[1:])
coordinate4 = 'HG02392_chrY:24666379-24895628'
CordSeq4 = ''.join(pysam.faidx(assemblyDict['HG02392'], coordinate4).split()[1:])
#with open('/Breakpoints/b2b3Inversion/alignments/HG02074_HG02392_b2b3Inversion_breakpoint.fasta', 'a+') as file:
    file.write('>'+str(coordinate1)+'_Front\n')
    file.write(CordSeq1+"\n")
    file.write('>'+str(coordinate2)+'_Back\n')
    file.write(str(CordSeq2).translate(comp)[::-1]+"\n")
    file.write('>'+str(coordinate3)+'_Front\n')
    file.write(CordSeq3+"\n")
    file.write('>'+str(coordinate4)+'_Back\n')
    file.write(str(CordSeq4).translate(comp)[::-1]+"\n")
file.close()

# %%
coordinate1 = 'HG01109_chrY:23855732-24084562'
CordSeq1 = ''.join(pysam.faidx(assemblyDict['HG01109'], coordinate1).split()[1:])
coordinate2 = 'HG01109_chrY:24811869-25065105'
CordSeq2 = ''.join(pysam.faidx(assemblyDict['HG01109'], coordinate2).split()[1:])
coordinate3 = 'NA19331_chrY:23943835-24197196'
CordSeq3 = ''.join(pysam.faidx(assemblyDict['NA19331'], coordinate3).split()[1:])
coordinate4 = 'NA19331_chrY:24919749-25148445'
CordSeq4 = ''.join(pysam.faidx(assemblyDict['NA19331'], coordinate4).split()[1:])
#with open('/Breakpoints/b2b3Inversion/alignments/HG01109_NA19331_b2b3Inversion_breakpoint.fasta', 'a+') as file:
    file.write('>'+str(coordinate1)+'_Front\n')
    file.write(CordSeq1+"\n")
    file.write('>'+str(coordinate2)+'_Back\n')
    file.write(str(CordSeq2).translate(comp)[::-1]+"\n")
    file.write('>'+str(coordinate3)+'_Front\n')
    file.write(CordSeq3+"\n")
    file.write('>'+str(coordinate4)+'_Back\n')
    file.write(str(CordSeq4).translate(comp)[::-1]+"\n")
file.close()

# %%
df[df['sample']=='HG03579']
# Out:
#     Unnamed: 0   sample        contig     colorblock orientation     start  \
# 29          57  HG03579  HG03579_chrY          blue1   antisense  23583710
# 30          58  HG03579  HG03579_chrY          teal2   antisense  23751410
# 31          59  HG03579  HG03579_chrY        spacer3       sense  23867103
# 32          60  HG03579  HG03579_chrY          teal2       sense  24036253
# 33          61  HG03579  HG03579_chrY          blue2       sense  24151937
# 34          62  HG03579  HG03579_chrY     blue2-plus       sense  24320448
# 35          63  HG03579  HG03579_chrY   blue3-bIR1-3       sense  24351140
# 36          64  HG03579  HG03579_chrY  green1-gIR1-2   antisense  24405628
# 37          65  HG03579  HG03579_chrY         green1   antisense  24413224
# 38          66  HG03579  HG03579_chrY           red2   antisense  24720635
# 39          67  HG03579  HG03579_chrY        spacer2   antisense  24876381
# ...

# %%
coordinate1 = 'NA20870_chrY:23498031-23726851'
CordSeq1 = ''.join(pysam.faidx(assemblyDict['NA20870'], coordinate1).split()[1:])
coordinate2 = 'NA20870_chrY:24435052-24688288'
CordSeq2 = ''.join(pysam.faidx(assemblyDict['NA20870'], coordinate2).split()[1:])
coordinate3 = 'HG03579_chrY:24151937-24405628'
CordSeq3 = ''.join(pysam.faidx(assemblyDict['HG03579'], coordinate3).split()[1:])
coordinate4 = 'HG03579_chrY:25140074-25368783'
CordSeq4 = ''.join(pysam.faidx(assemblyDict['HG03579'], coordinate4).split()[1:])
#with open('/LeeLab/HPRC/chromosomeY/Figures/Breakpoints/b2b3Inversion/alignments/NA20870_HG03579_b2b3Inversion_breakpoint.fasta', 'a+') as file:
    file.write('>'+str(coordinate1)+'_Front\n')
    file.write(CordSeq1+"\n")
    file.write('>'+str(coordinate2)+'_Back\n')
    file.write(str(CordSeq2).translate(comp)[::-1]+"\n")
    file.write('>'+str(coordinate3)+'_Front\n')
    file.write(CordSeq3+"\n")
    file.write('>'+str(coordinate4)+'_Back\n')
    file.write(str(CordSeq4).translate(comp)[::-1]+"\n")
file.close()
