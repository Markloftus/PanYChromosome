# %%
import pandas as pd
import pysam
import os
import json

# %%
comp = str.maketrans("ACGTNacgtn", "TGCANtgcan")
#rc = str(CordSeq3+CordSeq4).translate(comp)[::-1]

# %% [markdown]
# # assemblies

# %%
assemblyDict={}
directory='/LeeLab/Assemblies/HPRC_Release2/chrY_assemblies/'
for file in os.listdir(directory):
    if '.fai' in file or '.gzi' in file or '.DS' in file:
        continue
    else:
        assemblyDict[file.split("_")[0]]= directory+file
print(len(assemblyDict))
# Out:
# 143

# %%
df = pd.read_csv("/LeeLab/HPRC/chromosomeY/Data/DavidPorubsky/AZFc_ColorBLock_Clusters_12162025.csv")

# %% [markdown]
# ## pairings

# %%
#myt2tvshg38stylePairings=[
    #['HG01952','HG01928'], DONE in green block
    #['HG02071','HG00706'], DONE IN RED BLOCK
    #['HG02717','HG03471',],DONE IT IS IN GREEN BLOCK
    #['NA18620','HG02040']# #Breaks in the start of red
    #['NA18620','NA19705']# REDO with different from HG02040 - #Looks like it breaks in the start of the RED
    #['HG04199','HG01192'] Tip of red block
    #['HG02492','HG01167'],Takes place in the green block
    #['HG03688','HG01192'], #Looks like the break is in the second red group
    #['HG02514','HG02392'], #DONE IN THE GREEN
    #['HG02027','HG02392'], #Break in front of green different break point after IR1
    #['HG02083','HG02392'], #IN the green toward the end
    #['HG00642','200085'], Looks like it breaks between end of green and start of RED
    #['HG002','HG01167'],#It could be green or it could be red. Looks like there is some evidence for multiple break points
    #['HG01255','HG01167'], #Takes place in second RED
    #['HG01258','HG01167'],##Takes place in front of second red
#]

# %% [markdown]
# ## Pull sequences

# %%
df[df['sample']=='HG01167']
# Out:
#      Unnamed: 0   sample        contig     colorblock orientation     start  \
# 388         558  HG01167  HG01167_chrY          blue2   antisense  23204334
# 389         559  HG01167  HG01167_chrY          teal2   antisense  23372033
# 390         560  HG01167  HG01167_chrY        spacer3       sense  23487738
# 391         561  HG01167  HG01167_chrY          teal2       sense  23656752
# 392         562  HG01167  HG01167_chrY          blue1       sense  23772452
# 393         563  HG01167  HG01167_chrY     blue4-plus       sense  23940608
# 394         564  HG01167  HG01167_chrY   blue2-bIR1-2       sense  23971294
# 395         565  HG01167  HG01167_chrY  green1-gIR1-2   antisense  24025776
# 396         566  HG01167  HG01167_chrY         green3   antisense  24033372
# 397         567  HG01167  HG01167_chrY           red2   antisense  24340767
# 398         568  HG01167  HG01167_chrY        spacer2       sense  24477500
# ...

# %%
#
coordinate1 = 'HG01255_chrY:23977572-24429352'
CordSeq1 = ''.join(pysam.faidx(assemblyDict['HG01255'], coordinate1).split()[1:])
coordinate2 = 'HG01255_chrY:26054496-26501435'
CordSeq2 = ''.join(pysam.faidx(assemblyDict['HG01255'], coordinate2).split()[1:])
coordinate3 = 'HG01167_chrY:24025776-24477502'
CordSeq3 = ''.join(pysam.faidx(assemblyDict['HG01167'], coordinate3).split()[1:])
coordinate4 = 'HG01167_chrY:26094777-26552562'
CordSeq4 = ''.join(pysam.faidx(assemblyDict['HG01167'], coordinate4).split()[1:])
with open('/LeeLab/HPRC/chromosomeY/Figures/Breakpoints/T2Tvshg38/alignments/HG01255_HG01167_T2TvsGRCh38_JUSTACHECK.fasta', 'a+') as file:
    file.write('>'+str(coordinate1)+'_Front\n')
    file.write(CordSeq1+"\n")
    file.write('>'+str(coordinate2)+'_Back\n')
    file.write(str(CordSeq2).translate(comp)[::-1]+"\n")
    file.write('>'+str(coordinate3)+'_Front\n')
    file.write(CordSeq3+"\n")
    file.write('>'+str(coordinate4)+'_Back\n')
    file.write(str(CordSeq4).translate(comp)[::-1]+"\n")
file.close()

# %%
#It could be green or it could be red. Looks like there is some evidence for multiple break points
coordinate1 = 'HG002_chrY:24037327-24167147'
CordSeq1 = ''.join(pysam.faidx(assemblyDict['HG002'], coordinate1).split()[1:])
coordinate2 = 'HG002_chrY:25503520-25650235'
CordSeq2 = ''.join(pysam.faidx(assemblyDict['HG002'], coordinate2).split()[1:])
coordinate3 = 'HG01167_chrY:24479690-24626409'
CordSeq3 = ''.join(pysam.faidx(assemblyDict['HG01167'], coordinate3).split()[1:])
coordinate4 = 'HG01167_chrY:25962786-26092644'
CordSeq4 = ''.join(pysam.faidx(assemblyDict['HG01167'], coordinate4).split()[1:])
#with open('/LeeLab/HPRC/chromosomeY/Figures/Breakpoints/T2Tvshg38/alignments/HG002_HG01167_T2TvsGRCh38_VERSION2breakpoint.fasta', 'a+') as file:
    file.write('>'+str(coordinate1)+'_Front\n')
    file.write(CordSeq1+"\n")
    file.write('>'+str(coordinate2)+'_Back\n')
    file.write(str(CordSeq2).translate(comp)[::-1]+"\n")
    file.write('>'+str(coordinate3)+'_Front\n')
    file.write(CordSeq3+"\n")
    file.write('>'+str(coordinate4)+'_Back\n')
    file.write(str(CordSeq4).translate(comp)[::-1]+"\n")
file.close()

# %%
#Looks like it breaks between end of green and start of RED
coordinate1 = 'HG00642_chrY:23536173-24003523'
CordSeq1 = ''.join(pysam.faidx(assemblyDict['HG00642'], coordinate1).split()[1:])
coordinate2 = 'HG00642_chrY:25612872-26074363'
CordSeq2 = ''.join(pysam.faidx(assemblyDict['HG00642'], coordinate2).split()[1:])
coordinate3 = '200085_chrY:23533994-23995454'
CordSeq3 = ''.join(pysam.faidx(assemblyDict['200085'], coordinate3).split()[1:])
coordinate4 = '200085_chrY:25625775-26077452'
CordSeq4 = ''.join(pysam.faidx(assemblyDict['200085'], coordinate4).split()[1:])
#with open('/LeeLab/HPRC/chromosomeY/Figures/Breakpoints/T2Tvshg38/alignments/HG00642_200085_T2TvsGRCh38_breakpoint.fasta', 'a+') as file:
    file.write('>'+str(coordinate1)+'_Front\n')
    file.write(CordSeq1+"\n")
    file.write('>'+str(coordinate2)+'_Back\n')
    file.write(str(CordSeq2).translate(comp)[::-1]+"\n")
    file.write('>'+str(coordinate3)+'_Front\n')
    file.write(CordSeq3+"\n")
    file.write('>'+str(coordinate4)+'_Back\n')
    file.write(str(CordSeq4).translate(comp)[::-1]+"\n")
file.close()

# %%
#Looks like the break is in the second red group
coordinate1 = 'HG03688_chrY:24734194-24870165'
CordSeq1 = ''.join(pysam.faidx(assemblyDict['HG03688'], coordinate1).split()[1:])
coordinate2 = 'HG03688_chrY:26206531-26341154'
CordSeq2 = ''.join(pysam.faidx(assemblyDict['HG03688'], coordinate2).split()[1:])
coordinate3 = 'HG01192_chrY:24143169-24275410'
CordSeq3 = ''.join(pysam.faidx(assemblyDict['HG01192'], coordinate3).split()[1:])
coordinate4 = 'HG01192_chrY:25611743-25758527'
CordSeq4 = ''.join(pysam.faidx(assemblyDict['HG01192'], coordinate4).split()[1:])
with open('/LeeLab/HPRC/chromosomeY/Figures/Breakpoints/T2Tvshg38/alignments/HG03688_HG01192_T2TvsGRCh38_breakpoint.fasta', 'a+') as file:
    file.write('>'+str(coordinate1)+'_Front\n')
    file.write(CordSeq1+"\n")
    file.write('>'+str(coordinate2)+'_Back\n')
    file.write(str(CordSeq2).translate(comp)[::-1]+"\n")
    file.write('>'+str(coordinate3)+'_Front\n')
    file.write(CordSeq3+"\n")
    file.write('>'+str(coordinate4)+'_Back\n')
    file.write(str(CordSeq4).translate(comp)[::-1]+"\n")
file.close()

# %%
#Breaks in the start of red
coordinate1 = 'NA18620_chrY:24521107-24643811'
CordSeq1 = ''.join(pysam.faidx(assemblyDict['NA18620'], coordinate1).split()[1:])
coordinate2 = 'NA18620_chrY:26266365-26417931'
CordSeq2 = ''.join(pysam.faidx(assemblyDict['NA18620'], coordinate2).split()[1:])
coordinate3 = 'HG02040_chrY:24630087-24767064'
CordSeq3 = ''.join(pysam.faidx(assemblyDict['HG02040'], coordinate3).split()[1:])
coordinate4 = 'HG02040_chrY:26401951-26534176'
CordSeq4 = ''.join(pysam.faidx(assemblyDict['HG02040'], coordinate4).split()[1:])
#with open('/LeeLab/HPRC/chromosomeY/Figures/Breakpoints/T2Tvshg38/alignments/NA18620_HG02040_T2TvsGRCh38_REDObreakpoint.fasta', 'a+') as file:
    file.write('>'+str(coordinate1)+'_Front\n')
    file.write(CordSeq1+"\n")
    file.write('>'+str(coordinate2)+'_Back\n')
    file.write(str(CordSeq2).translate(comp)[::-1]+"\n")
    file.write('>'+str(coordinate3)+'_Front\n')
    file.write(CordSeq3+"\n")
    file.write('>'+str(coordinate4)+'_Back\n')
    file.write(str(CordSeq4).translate(comp)[::-1]+"\n")
file.close()

# %%
#Looks like it breaks in the start of the RED
coordinate1 = 'NA18620_chrY:24206397-24643811'
CordSeq1 = ''.join(pysam.faidx(assemblyDict['NA18620'], coordinate1).split()[1:])
coordinate2 = 'NA18620_chrY:26266365-26732642'
CordSeq2 = ''.join(pysam.faidx(assemblyDict['NA18620'], coordinate2).split()[1:])
coordinate3 = 'NA19705_chrY:24882240-25341091'
CordSeq3 = ''.join(pysam.faidx(assemblyDict['NA19705'], coordinate3).split()[1:])
coordinate4 = 'NA19705_chrY:26948077-27403456'
CordSeq4 = ''.join(pysam.faidx(assemblyDict['NA19705'], coordinate4).split()[1:])
#with open('/LeeLab/HPRC/chromosomeY/Figures/Breakpoints/T2Tvshg38/alignments/NA18620_NA19705_T2TvsGRCh38_breakpoint.fasta', 'a+') as file:
    file.write('>'+str(coordinate1)+'_Front\n')
    file.write(CordSeq1+"\n")
    file.write('>'+str(coordinate2)+'_Back\n')
    file.write(str(CordSeq2).translate(comp)[::-1]+"\n")
    file.write('>'+str(coordinate3)+'_Front\n')
    file.write(CordSeq3+"\n")
    file.write('>'+str(coordinate4)+'_Back\n')
    file.write(str(CordSeq4).translate(comp)[::-1]+"\n")
file.close()

# %%
#Takes place in front of second red
coordinate1 = 'HG01258_chrY:24544072-24690788'
CordSeq1 = ''.join(pysam.faidx(assemblyDict['HG01258'], coordinate1).split()[1:])
coordinate2 = 'HG01258_chrY:26026578-26164885'
CordSeq2 = ''.join(pysam.faidx(assemblyDict['HG01258'], coordinate2).split()[1:])
coordinate3 = 'HG01167_chrY:24479689-24626409'
CordSeq3 = ''.join(pysam.faidx(assemblyDict['HG01167'], coordinate3).split()[1:])
coordinate4 = 'HG01167_chrY:25962786-26092644'
CordSeq4 = ''.join(pysam.faidx(assemblyDict['HG01167'], coordinate4).split()[1:])
#with open('/LeeLab/HPRC/chromosomeY/Figures/Breakpoints/T2Tvshg38/alignments/HG01258_HG01167_T2TvsGRCh38_Redbreakpoint.fasta', 'a+') as file:
    file.write('>'+str(coordinate1)+'_Front\n')
    file.write(CordSeq1+"\n")
    file.write('>'+str(coordinate2)+'_Back\n')
    file.write(str(CordSeq2).translate(comp)[::-1]+"\n")
    file.write('>'+str(coordinate3)+'_Front\n')
    file.write(CordSeq3+"\n")
    file.write('>'+str(coordinate4)+'_Back\n')
    file.write(str(CordSeq4).translate(comp)[::-1]+"\n")
file.close()

# %%
#Takes place in second RED
coordinate1 = 'HG01255_chrY:24431539-24578259'
CordSeq1 = ''.join(pysam.faidx(assemblyDict['HG01255'], coordinate1).split()[1:])
coordinate2 = 'HG01255_chrY:25914055-26052363'
CordSeq2 = ''.join(pysam.faidx(assemblyDict['HG01255'], coordinate2).split()[1:])
coordinate3 = 'HG01167_chrY:24479689-24626409'
CordSeq3 = ''.join(pysam.faidx(assemblyDict['HG01167'], coordinate3).split()[1:])
coordinate4 = 'HG01167_chrY:25962786-26092644'
CordSeq4 = ''.join(pysam.faidx(assemblyDict['HG01167'], coordinate4).split()[1:])
#with open('/LeeLab/HPRC/chromosomeY/Figures/Breakpoints/T2Tvshg38/alignments/HG01255_HG01167_T2TvsGRCh38_Redbreakpoint.fasta', 'a+') as file:
    file.write('>'+str(coordinate1)+'_Front\n')
    file.write(CordSeq1+"\n")
    file.write('>'+str(coordinate2)+'_Back\n')
    file.write(str(CordSeq2).translate(comp)[::-1]+"\n")
    file.write('>'+str(coordinate3)+'_Front\n')
    file.write(CordSeq3+"\n")
    file.write('>'+str(coordinate4)+'_Back\n')
    file.write(str(CordSeq4).translate(comp)[::-1]+"\n")
file.close()

# %%
#From Green- Red its inconclusive. Will check further second red
coordinate1 = 'HG01255_chrY:23985168-24429352'
CordSeq1 = ''.join(pysam.faidx(assemblyDict['HG01255'], coordinate1).split()[1:])
coordinate2 = 'HG01255_chrY:26054496-26493839'
CordSeq2 = ''.join(pysam.faidx(assemblyDict['HG01255'], coordinate2).split()[1:])
coordinate3 = 'HG01167_chrY:24033372-24477502'
CordSeq3 = ''.join(pysam.faidx(assemblyDict['HG01167'], coordinate3).split()[1:])
coordinate4 = 'HG01167_chrY:26094777-26544969'
CordSeq4 = ''.join(pysam.faidx(assemblyDict['HG01167'], coordinate4).split()[1:])
#with open('/LeeLab/HPRC/chromosomeY/Figures/Breakpoints/T2Tvshg38/alignments/HG01255_HG01167_T2TvsGRCh38_breakpoint.fasta', 'a+') as file:
    file.write('>'+str(coordinate1)+'_Front\n')
    file.write(CordSeq1+"\n")
    file.write('>'+str(coordinate2)+'_Back\n')
    file.write(str(CordSeq2).translate(comp)[::-1]+"\n")
    file.write('>'+str(coordinate3)+'_Front\n')
    file.write(CordSeq3+"\n")
    file.write('>'+str(coordinate4)+'_Back\n')
    file.write(str(CordSeq4).translate(comp)[::-1]+"\n")
file.close()

# %%
#It could be green or it could be red. Looks like there is some evidence for multiple break points
coordinate1 = 'HG002_chrY:23589686-24035139'
CordSeq1 = ''.join(pysam.faidx(assemblyDict['HG002'], coordinate1).split()[1:])
coordinate2 = 'HG002_chrY:25652422-26094233'
CordSeq2 = ''.join(pysam.faidx(assemblyDict['HG002'], coordinate2).split()[1:])
coordinate3 = 'HG01167_chrY:24033372-24477502'
CordSeq3 = ''.join(pysam.faidx(assemblyDict['HG01167'], coordinate3).split()[1:])
coordinate4 = 'HG01167_chrY:26094777-26544969'
CordSeq4 = ''.join(pysam.faidx(assemblyDict['HG01167'], coordinate4).split()[1:])
#with open('/LeeLab/HPRC/chromosomeY/Figures/Breakpoints/T2Tvshg38/alignments/HG002_HG01167_T2TvsGRCh38_breakpoint.fasta', 'a+') as file:
    file.write('>'+str(coordinate1)+'_Front\n')
    file.write(CordSeq1+"\n")
    file.write('>'+str(coordinate2)+'_Back\n')
    file.write(str(CordSeq2).translate(comp)[::-1]+"\n")
    file.write('>'+str(coordinate3)+'_Front\n')
    file.write(CordSeq3+"\n")
    file.write('>'+str(coordinate4)+'_Back\n')
    file.write(str(CordSeq4).translate(comp)[::-1]+"\n")
file.close()

# %%
#Looks like it breaks between end of green and start of RED
coordinate1 = 'HG00642_chrY:23850908-24003523'
CordSeq1 = ''.join(pysam.faidx(assemblyDict['HG00642'], coordinate1).split()[1:])
coordinate2 = 'HG00642_chrY:25612872-25759654'
CordSeq2 = ''.join(pysam.faidx(assemblyDict['HG00642'], coordinate2).split()[1:])
coordinate3 = '200085_chrY:23848710-23995454'
CordSeq3 = ''.join(pysam.faidx(assemblyDict['200085'], coordinate3).split()[1:])
coordinate4 = '200085_chrY:25625775-25762759'
CordSeq4 = ''.join(pysam.faidx(assemblyDict['200085'], coordinate4).split()[1:])
#with open('/LeeLab/HPRC/chromosomeY/Figures/Breakpoints/T2Tvshg38/alignments/HG00642_200085_T2TvsGRCh38_REDbreakpoint.fasta', 'a+') as file:
    file.write('>'+str(coordinate1)+'_Front\n')
    file.write(CordSeq1+"\n")
    file.write('>'+str(coordinate2)+'_Back\n')
    file.write(str(CordSeq2).translate(comp)[::-1]+"\n")
    file.write('>'+str(coordinate3)+'_Front\n')
    file.write(CordSeq3+"\n")
    file.write('>'+str(coordinate4)+'_Back\n')
    file.write(str(CordSeq4).translate(comp)[::-1]+"\n")
file.close()

# %%
#NOT IN THE GREEN - THIS PULLS GREEN COORDINATES
coordinate1 = 'HG00642_chrY:23536173-23851202'
CordSeq1 = ''.join(pysam.faidx(assemblyDict['HG00642'], coordinate1).split()[1:])
coordinate2 = 'HG00642_chrY:25759359-26074363'
CordSeq2 = ''.join(pysam.faidx(assemblyDict['HG00642'], coordinate2).split()[1:])
coordinate3 = '200085_chrY:23533994-23849002'
CordSeq3 = ''.join(pysam.faidx(assemblyDict['200085'], coordinate3).split()[1:])
coordinate4 = '200085_chrY:25762465-26077452'
CordSeq4 = ''.join(pysam.faidx(assemblyDict['200085'], coordinate4).split()[1:])
#with open('/LeeLab/HPRC/chromosomeY/Figures/Breakpoints/T2Tvshg38/alignments/HG00642_200085_T2TvsGRCh38_breakpoint.fasta', 'a+') as file:
    file.write('>'+str(coordinate1)+'_Front\n')
    file.write(CordSeq1+"\n")
    file.write('>'+str(coordinate2)+'_Back\n')
    file.write(str(CordSeq2).translate(comp)[::-1]+"\n")
    file.write('>'+str(coordinate3)+'_Front\n')
    file.write(CordSeq3+"\n")
    file.write('>'+str(coordinate4)+'_Back\n')
    file.write(str(CordSeq4).translate(comp)[::-1]+"\n")
file.close()

# %%
#IN the green toward the end
coordinate1 = 'HG02083_chrY:23073795-23388800'
CordSeq1 = ''.join(pysam.faidx(assemblyDict['HG02083'], coordinate1).split()[1:])
coordinate2 = 'HG02083_chrY:25311841-25626864'
CordSeq2 = ''.join(pysam.faidx(assemblyDict['HG02083'], coordinate2).split()[1:])
coordinate3 = 'HG02392_chrY:23943836-24258862'
CordSeq3 = ''.join(pysam.faidx(assemblyDict['HG02392'], coordinate3).split()[1:])
coordinate4 = 'HG02392_chrY:26167571-26482590'
CordSeq4 = ''.join(pysam.faidx(assemblyDict['HG02392'], coordinate4).split()[1:])
#with open('/LeeLab/HPRC/chromosomeY/Figures/Breakpoints/T2Tvshg38/alignments/HG02083_HG02392_T2TvsGRCh38_breakpoint.fasta', 'a+') as file:
    file.write('>'+str(coordinate1)+'_Front\n')
    file.write(CordSeq1+"\n")
    file.write('>'+str(coordinate2)+'_Back\n')
    file.write(str(CordSeq2).translate(comp)[::-1]+"\n")
    file.write('>'+str(coordinate3)+'_Front\n')
    file.write(CordSeq3+"\n")
    file.write('>'+str(coordinate4)+'_Back\n')
    file.write(str(CordSeq4).translate(comp)[::-1]+"\n")
file.close()

# %%
#Break in front of green different break point after IR1
coordinate1 = 'HG02027_chrY:23660370-23975383'
CordSeq1 = ''.join(pysam.faidx(assemblyDict['HG02027'], coordinate1).split()[1:])
coordinate2 = 'HG02027_chrY:25895858-26210889'
CordSeq2 = ''.join(pysam.faidx(assemblyDict['HG02027'], coordinate2).split()[1:])
coordinate3 = 'HG02392_chrY:23943836-24258862'
CordSeq3 = ''.join(pysam.faidx(assemblyDict['HG02392'], coordinate3).split()[1:])
coordinate4 = 'HG02392_chrY:26167571-26482590'
CordSeq4 = ''.join(pysam.faidx(assemblyDict['HG02392'], coordinate4).split()[1:])
#with open('/LeeLab/HPRC/chromosomeY/Figures/Breakpoints/T2Tvshg38/alignments/HG02027_HG02392_T2TvsGRCh38_breakpoint.fasta', 'a+') as file:
    file.write('>'+str(coordinate1)+'_Front\n')
    file.write(CordSeq1+"\n")
    file.write('>'+str(coordinate2)+'_Back\n')
    file.write(str(CordSeq2).translate(comp)[::-1]+"\n")
    file.write('>'+str(coordinate3)+'_Front\n')
    file.write(CordSeq3+"\n")
    file.write('>'+str(coordinate4)+'_Back\n')
    file.write(str(CordSeq4).translate(comp)[::-1]+"\n")
file.close()

# %%
#DONE IN THE GREEN
coordinate1 = 'HG02514_chrY:23669301-23984321'
CordSeq1 = ''.join(pysam.faidx(assemblyDict['HG02514'], coordinate1).split()[1:])
coordinate2 = 'HG02514_chrY:25886955-26201964'
CordSeq2 = ''.join(pysam.faidx(assemblyDict['HG02514'], coordinate2).split()[1:])
coordinate3 = 'HG02392_chrY:23943836-24258862'
CordSeq3 = ''.join(pysam.faidx(assemblyDict['HG02392'], coordinate3).split()[1:])
coordinate4 = 'HG02392_chrY:26167571-26482590'
CordSeq4 = ''.join(pysam.faidx(assemblyDict['HG02392'], coordinate4).split()[1:])
#with open('/LeeLab/HPRC/chromosomeY/Figures/Breakpoints/T2Tvshg38/alignments/HG02514_HG02392_T2TvsGRCh38_breakpoint.fasta', 'a+') as file:
    file.write('>'+str(coordinate1)+'_Front\n')
    file.write(CordSeq1+"\n")
    file.write('>'+str(coordinate2)+'_Back\n')
    file.write(str(CordSeq2).translate(comp)[::-1]+"\n")
    file.write('>'+str(coordinate3)+'_Front\n')
    file.write(CordSeq3+"\n")
    file.write('>'+str(coordinate4)+'_Back\n')
    file.write(str(CordSeq4).translate(comp)[::-1]+"\n")
file.close()

# %%
#DIDNT PULL SINCE I HAVE HG04199 which is closely related with same architecture
coordinate1 = 'HG03688_chrY:'
CordSeq1 = ''.join(pysam.faidx(assemblyDict['HG03688'], coordinate1).split()[1:])
coordinate2 = 'HG03688_chrY:'
CordSeq2 = ''.join(pysam.faidx(assemblyDict['HG03688'], coordinate2).split()[1:])
coordinate3 = 'HG01192_chrY:'
CordSeq3 = ''.join(pysam.faidx(assemblyDict['HG01192'], coordinate3).split()[1:])
coordinate4 = 'HG01192_chrY:'
CordSeq4 = ''.join(pysam.faidx(assemblyDict['HG01192'], coordinate4).split()[1:])
#with open('/LeeLab/HPRC/chromosomeY/Figures/Breakpoints/T2Tvshg38/alignments/HG03688_HG01192_T2TvsGRCh38_breakpoint.fasta', 'a+') as file:
    file.write('>'+str(coordinate1)+'_Front\n')
    file.write(CordSeq1+"\n")
    file.write('>'+str(coordinate2)+'_Back\n')
    file.write(str(CordSeq2).translate(comp)[::-1]+"\n")
    file.write('>'+str(coordinate3)+'_Front\n')
    file.write(CordSeq3+"\n")
    file.write('>'+str(coordinate4)+'_Back\n')
    file.write(str(CordSeq4).translate(comp)[::-1]+"\n")
file.close()

# %%
#Takes place in the green block
coordinate1 = 'HG02492_chrY:23407319-23722331'
CordSeq1 = ''.join(pysam.faidx(assemblyDict['HG02492'], coordinate1).split()[1:])
coordinate2 = 'HG02492_chrY:25609540-25924529'
CordSeq2 = ''.join(pysam.faidx(assemblyDict['HG02492'], coordinate2).split()[1:])
coordinate3 = 'HG01167_chrY:24025776-24340767'
CordSeq3 = ''.join(pysam.faidx(assemblyDict['HG01167'], coordinate3).split()[1:])
coordinate4 = 'HG01167_chrY:26237564-26552562'
CordSeq4 = ''.join(pysam.faidx(assemblyDict['HG01167'], coordinate4).split()[1:])
#with open('/LeeLab/HPRC/chromosomeY/Figures/Breakpoints/T2Tvshg38/alignments/HG02492_HG01167_T2TvsGRCh38_breakpoint.fasta', 'a+') as file:
    file.write('>'+str(coordinate1)+'_Front\n')
    file.write(CordSeq1+"\n")
    file.write('>'+str(coordinate2)+'_Back\n')
    file.write(str(CordSeq2).translate(comp)[::-1]+"\n")
    file.write('>'+str(coordinate3)+'_Front\n')
    file.write(CordSeq3+"\n")
    file.write('>'+str(coordinate4)+'_Back\n')
    file.write(str(CordSeq4).translate(comp)[::-1]+"\n")
file.close()

# %%
#Tip of REd blocks
coordinate1 = 'HG04199_chrY:24765914-24901870'
CordSeq1 = ''.join(pysam.faidx(assemblyDict['HG04199'], coordinate1).split()[1:])
coordinate2 = 'HG04199_chrY:26238165-26384896'
CordSeq2 = ''.join(pysam.faidx(assemblyDict['HG04199'], coordinate2).split()[1:])
coordinate3 = 'HG01192_chrY:24143169-24275410'
CordSeq3 = ''.join(pysam.faidx(assemblyDict['HG01192'], coordinate3).split()[1:])
coordinate4 = 'HG01192_chrY:25611743-25758527'
CordSeq4 = ''.join(pysam.faidx(assemblyDict['HG01192'], coordinate4).split()[1:])
#with open('/LeeLab/HPRC/chromosomeY/Figures/Breakpoints/T2Tvshg38/alignments/HG04199_HG01192_T2TvsGRCh38_breakpoint.fasta', 'a+') as file:
    file.write('>'+str(coordinate1)+'_Front\n')
    file.write(CordSeq1+"\n")
    file.write('>'+str(coordinate2)+'_Back\n')
    file.write(str(CordSeq2).translate(comp)[::-1]+"\n")
    file.write('>'+str(coordinate3)+'_Front\n')
    file.write(CordSeq3+"\n")
    file.write('>'+str(coordinate4)+'_Back\n')
    file.write(str(CordSeq4).translate(comp)[::-1]+"\n")
file.close()

# %%
#CURSED looks like green but I have a feeling 2040 is not a great assembly to compare against. 
coordinate1 = 'NA18620_chrY:24206397-24521394'
CordSeq1 = ''.join(pysam.faidx(assemblyDict['NA18620'], coordinate1).split()[1:])
coordinate2 = 'NA18620_chrY:26417642-26732642'
CordSeq2 = ''.join(pysam.faidx(assemblyDict['NA18620'], coordinate2).split()[1:])
coordinate3 = 'HG02040_chrY:24315357-24630382'
CordSeq3 = ''.join(pysam.faidx(assemblyDict['HG02040'], coordinate3).split()[1:])
coordinate4 = 'HG02040_chrY:26533887-26848888'
CordSeq4 = ''.join(pysam.faidx(assemblyDict['HG02040'], coordinate4).split()[1:])
#with open('/LeeLab/HPRC/chromosomeY/Figures/Breakpoints/T2Tvshg38/alignments/NA18620_HG02040_T2TvsGRCh38_breakpoint.fasta', 'a+') as file:
    file.write('>'+str(coordinate1)+'_Front\n')
    file.write(CordSeq1+"\n")
    file.write('>'+str(coordinate2)+'_Back\n')
    file.write(str(CordSeq2).translate(comp)[::-1]+"\n")
    file.write('>'+str(coordinate3)+'_Front\n')
    file.write(CordSeq3+"\n")
    file.write('>'+str(coordinate4)+'_Back\n')
    file.write(str(CordSeq4).translate(comp)[::-1]+"\n")
file.close()

# %%
#DONE IT IS IN GREEN BLOCK
coordinate1 = 'HG02717_chrY:24391593-24706555'
CordSeq1 = ''.join(pysam.faidx(assemblyDict['HG02717'], coordinate1).split()[1:])
coordinate2 = 'HG02717_chrY:26597786-26912782'
CordSeq2 = ''.join(pysam.faidx(assemblyDict['HG02717'], coordinate2).split()[1:])
coordinate3 = 'HG03471_chrY:24416081-24731044'
CordSeq3 = ''.join(pysam.faidx(assemblyDict['HG03471'], coordinate3).split()[1:])
coordinate4 = 'HG03471_chrY:26622338-26937305'
CordSeq4 = ''.join(pysam.faidx(assemblyDict['HG03471'], coordinate4).split()[1:])
#with open('/LeeLab/HPRC/chromosomeY/Figures/Breakpoints/T2Tvshg38/alignments/HG02717_HG03471_T2TvsGRCh38_breakpoint.fasta', 'a+') as file:
    file.write('>'+str(coordinate1)+'_Front\n')
    file.write(CordSeq1+"\n")
    file.write('>'+str(coordinate2)+'_Back\n')
    file.write(str(CordSeq2).translate(comp)[::-1]+"\n")
    file.write('>'+str(coordinate3)+'_Front\n')
    file.write(CordSeq3+"\n")
    file.write('>'+str(coordinate4)+'_Back\n')
    file.write(str(CordSeq4).translate(comp)[::-1]+"\n")
file.close()

# %%
#DONE NOT IN GREEN FOR THIS ONE but RED
coordinate1 = 'HG02071_chrY:23764059-24079049'
CordSeq1 = ''.join(pysam.faidx(assemblyDict['HG02071'], coordinate1).split()[1:])
coordinate2 = 'HG02071_chrY:25999685-26314707'
CordSeq2 = ''.join(pysam.faidx(assemblyDict['HG02071'], coordinate2).split()[1:])
coordinate3 = 'HG00706_chrY:24020165-24335143'
CordSeq3 = ''.join(pysam.faidx(assemblyDict['HG00706'], coordinate3).split()[1:])
coordinate4 = 'HG00706_chrY:26236742-26551771'
CordSeq4 = ''.join(pysam.faidx(assemblyDict['HG00706'], coordinate4).split()[1:])
#with open('/LeeLab/HPRC/chromosomeY/Figures/Breakpoints/T2Tvshg38/alignments/HG02071_HG00706_T2TvsGRCh38_GreenUpstreambreakpoint.fasta', 'a+') as file:
    file.write('>'+str(coordinate1)+'_Front\n')
    file.write(CordSeq1+"\n")
    file.write('>'+str(coordinate2)+'_Back\n')
    file.write(str(CordSeq2).translate(comp)[::-1]+"\n")
    file.write('>'+str(coordinate3)+'_Front\n')
    file.write(CordSeq3+"\n")
    file.write('>'+str(coordinate4)+'_Back\n')
    file.write(str(CordSeq4).translate(comp)[::-1]+"\n")
file.close()

# %%
#DONE in green block
coordinate1 = 'HG01952_chrY:24404919-24719951'
CordSeq1 = ''.join(pysam.faidx(assemblyDict['HG01952'], coordinate1).split()[1:])
coordinate2 = 'HG01952_chrY:26618598-26933635'
CordSeq2 = ''.join(pysam.faidx(assemblyDict['HG01952'], coordinate2).split()[1:])
coordinate3 = 'HG01928_chrY:24236370-24551389'
CordSeq3 = ''.join(pysam.faidx(assemblyDict['HG01928'], coordinate3).split()[1:])
coordinate4 = 'HG01928_chrY:26445324-26760327'
CordSeq4 = ''.join(pysam.faidx(assemblyDict['HG01928'], coordinate4).split()[1:])
#with open('/LeeLab/HPRC/chromosomeY/Figures/Breakpoints/T2Tvshg38/alignments/HG01952_HG01928_T2TvsGRCh38_breakpoint.fasta', 'a+') as file:
    file.write('>'+str(coordinate1)+'_Front\n')
    file.write(CordSeq1+"\n")
    file.write('>'+str(coordinate2)+'_Back\n')
    file.write(str(CordSeq2).translate(comp)[::-1]+"\n")
    file.write('>'+str(coordinate3)+'_Front\n')
    file.write(CordSeq3+"\n")
    file.write('>'+str(coordinate4)+'_Back\n')
    file.write(str(CordSeq4).translate(comp)[::-1]+"\n")
file.close()
